-- %% [markdown]
-- # [dbo].[ChatImageTable]

-- %%
USE [FinalyearProject]
GO

-- %%
/****** Object:  Table [dbo].[ChatImageTable]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ChatImageTable](
	[Num] [varchar](100) NULL,
	[Image] [varbinary](max) NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ChatTable]

-- %%
/****** Object:  Table [dbo].[ChatTable]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ChatTable](
	[fromFid] [varchar](16) NULL,
	[toFid] [varchar](16) NULL,
	[msg] [varchar](1000) NULL,
	[Mdate] [datetime] NULL,
	[Mode] [varchar](1) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Dist]

-- %%
/****** Object:  Table [dbo].[Dist]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Dist](
	[cDistCode] [char](5) NOT NULL,
	[cDistName] [char](100) NOT NULL,
	[cStateCode] [char](2) NULL,
PRIMARY KEY CLUSTERED 
(
	[cDistCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Education]

-- %%
/****** Object:  Table [dbo].[Education]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Education](
	[Fid] [varchar](16) NULL,
	[educationStatus] [varchar](100) NULL,
	[Eid] [varchar](100) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FriendInfo]

-- %%
/****** Object:  Table [dbo].[FriendInfo]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FriendInfo](
	[Fid] [varchar](16) NOT NULL,
	[Fname] [varchar](50) NULL,
	[Lname] [varchar](50) NULL,
	[Phone] [varchar](10) NULL,
	[Gender] [varchar](1) NULL,
	[DOB] [date] NULL,
	[yymmdd] [varchar](8) NULL,
	[id] [varchar](8) NULL,
	[Upassword] [varchar](8) NULL,
	[Image] [varbinary](max) NULL,
	[maritalStatus] [varchar](30) NULL,
	[sc] [char](2) NULL,
	[dc] [varchar](5) NULL,
	[UserId] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Fid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FriendList]

-- %%
/****** Object:  Table [dbo].[FriendList]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FriendList](
	[Fid] [varchar](16) NULL,
	[FriendId] [varchar](16) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FriendRequest]

-- %%
/****** Object:  Table [dbo].[FriendRequest]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FriendRequest](
	[Fid] [varchar](16) NULL,
	[RFid] [varchar](16) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LiveUser]

-- %%
/****** Object:  Table [dbo].[LiveUser]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LiveUser](
	[Fid] [varchar](16) NULL,
	[LiveInfo] [varchar](1) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[State]

-- %%
/****** Object:  Table [dbo].[State]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[State](
	[cStateCode] [char](2) NOT NULL,
	[cStateName] [char](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[cStateCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vf]

-- %%
/****** Object:  Table [dbo].[vf]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[vf](
	[otp] [numeric](4, 0) NULL,
	[tm] [datetime] NULL,
	[Email] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vf2]

-- %%
/****** Object:  Table [dbo].[vf2]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[vf2](
	[Email] [varchar](50) NULL,
	[otp] [numeric](4, 0) NULL,
	[tm] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Working]

-- %%
/****** Object:  Table [dbo].[Working]    Script Date: 7/13/2024 11:48:13 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Working](
	[Fid] [varchar](16) NULL,
	[workingStatus] [varchar](100) NULL,
	[Wid] [varchar](100) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ChatImageTable]

-- %%
INSERT [dbo].[ChatImageTable] ([Num], [Image]) VALUES (N'1', ...)
INSERT [dbo].[ChatImageTable] ([Num], [Image]) VALUES (N'3', ...)
INSERT [dbo].[ChatImageTable] ([Num], [Image]) VALUES (N'4', ...)
INSERT [dbo].[ChatImageTable] ([Num], [Image]) VALUES (N'5', ...)
INSERT [dbo].[ChatImageTable] ([Num], [Image]) VALUES (N'6', ...)
INSERT [dbo].[ChatImageTable] ([Num], [Image]) VALUES (N'7', ...)
INSERT [dbo].[ChatImageTable] ([Num], [Image]) VALUES (N'8', ...)
INSERT [dbo].[ChatImageTable] ([Num], [Image]) VALUES (N'2', ...)
GO

-- %% [markdown]
-- # [dbo].[ChatTable]

-- %%
INSERT [dbo].[ChatTable] ([fromFid], [toFid], [msg], [Mdate], [Mode]) VALUES (N'202406071', N'202406091', N'5', CAST(N'2024-06-09T00:36:51.540' AS DateTime), N'1')
INSERT [dbo].[ChatTable] ([fromFid], [toFid], [msg], [Mdate], [Mode]) VALUES (N'202406071', N'202406072', N'hiiii', CAST(N'2024-06-12T13:17:48.420' AS DateTime), N'0')
INSERT [dbo].[ChatTable] ([fromFid], [toFid], [msg], [Mdate], [Mode]) VALUES (N'202406072', N'202406074', N'2', CAST(N'2024-06-07T20:28:56.753' AS DateTime), N'1')
INSERT [dbo].[ChatTable] ([fromFid], [toFid], [msg], [Mdate], [Mode]) VALUES (N'202
', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'732  ', N'JALPAIGURI                                                                                          ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'733  ', N'JHARGRAM                                                                                            ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'734  ', N'KALIMPONG                                                                                           ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'735  ', N'KOLKATA                                                                                             ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'736  ', N'MALDA                                                                                               ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'737  ', N'MURSHIDABAD                                                                                         ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'738  ', N'NADIA                                                                                               ', N'37')
GO

-- %%
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'739  ', N'NORTH 24 PARGANAS                                                                                   ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'74   ', N'UDALGURI                                                                                            ', N'4 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'740  ', N'PASCHIM BARDHAMAN                                                                                   ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'741  ', N'PASCHIM MEDINIPUR                                                                                   ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'742  ', N'PURBA BARDHAMAN                                                                                     ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'743  ', N'PURBA MEDINIPUR                                                                                     ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'744  ', N'PURULIA                                                                                             ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'745  ', N'SOUTH 24 PARGANAS                                                                                   ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'746  ', N'UTTAR DINAJPUR                                                                                      ', N'37')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'75   ', N'WEST KARBI ANGLONG                                                                                  ', N'4 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'76   ', N'ARARIA                                                                                              ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'77   ', N'ARWAL                                                                                               ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'78   ', N'AURANGABAD                                                                                          ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'79   ', N'BANKA                                                                                               ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'80   ', N'BEGUSARAI                                                                                           ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'81   ', N'BHAGALPUR                                                                                           ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'82   ', N'BHOJPUR                                                                                             ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'83   ', N'BUXAR                                                                                               ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'84   ', N'DARBHANGA                                                                                           ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'85   ', N'EAST CHAMPARAN                                                                                      ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'86   ', N'GAYA                                                                                                ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'87   ', N'GOPALGANJ                                                                                           ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'88   ', N'JAMUI                                                                                               ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'89   ', N'JEHANABAD                                                                                           ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'90   ', N'KAIMUR                                                                                              ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'91   ', N'KATIHAR                                                                                             ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'92   ', N'KHAGARIA                                                                                            ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'93   ', N'KISHANGANJ                                                                                          ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'94   ', N'LAKHISARAI                                                                                          ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'95   ', N'MADHEPURA                                                                                           ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'96   ', N'MADHUBANI                                                                                           ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'97   ', N'MUNGER                                                                                              ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'98   ', N'MUZAFFARPUR                                                                                         ', N'5 ')
INSERT [dbo].[Dist] ([cDistCode], [cDistName], [cStateCode]) VALUES (N'99   ', N'NALANDA                                                                                             ', N'5 ')
GO

-- %% [markdown]
-- # [dbo].[Education]

-- %%
INSERT [dbo].[Education] ([Fid], [educationStatus], [Eid]) VALUES (N'202406074', N'MP from RKMVVM', N'5')
INSERT [dbo].[Education] ([Fid], [educationStatus], [Eid]) VALUES (N'202406072', N'mp from rkmvvm', N'2')
INSERT [dbo].[Education] ([Fid], [educationStatus], [Eid]) VALUES (N'202406072', N'bca from ugb', N'3')
INSERT [dbo].[Education] ([Fid], [educationStatus], [Eid]) VALUES (N'202406121', N'BCA from ugb', N'4')
INSERT [dbo].[Education] ([Fid], [educationStatus], [Eid]) VALUES (N'202406074', N'HS from ACI', N'6')
GO

-- %% [markdown]
-- # [dbo].[FriendInfo]

-- %%
INSERT [dbo].[FriendInfo] ([Fid], [Fname], [Lname], [Phone], [Gender], [DOB], [yymmdd], [id], [Upassword], [Image], [maritalStatus], [sc], [dc], [UserId]) VALUES (N'202406071', N'P', N'TALUKDAR', N'9999999999', N'M', CAST(N'2024-06-07' AS Date), N'202467', N'1', N'GGgg@@99', ..., N'Not mentioned', N'37', N'736  ', N'prit@gmail.com')
INSERT [dbo].[FriendInfo] ([Fid], [Fname], [Lname], [Phone], [Gender], [DOB], [yymmdd], [id], [Upassword], [Image], [maritalStatus], [sc], [dc], [UserId]) VALUES (N'202406072', N'GARGA', N'SAHA', N'8670794073', N'M', CAST(N'2024-06-07' AS Date), N'202467', N'2', N'GGgg@@99', ..., N'Not mentioned', N'37', N'736  ', N'garga@gmail.com')
INSERT [dbo].[FriendInfo] ([Fid], [Fname], [Lname], [Phone], [Gender], [DOB], [yymmdd], [id], [Upassword], [Image], [maritalStatus], [sc], [dc], [UserId]) VALUES (N'202406073', N'MADHURIMA', N'ROY', N'9999999999', N'F', CAST(N'2024-06-07' AS Date), N'202467', N'3', N'GGgg@@99', ..., N'Not mentioned', N'37', N'736  ', N'madhu@gmail.com')
INSERT [dbo].[FriendInfo] ([Fid], [Fname], [Lname], [Phone], [Gender], [DOB], [yymmdd], [id], [Upassword], [Image], [maritalStatus], [sc], [dc], [UserId]) VALUES (N'202406074', N'NEHA', N'SAHA', N'9999999999', N'F', CAST(N'2024-06-07' AS Date), N'202467', N'4', N'GGgg@@99', ..., N'Married', N'01', N'02   ', N'neha@gmail.com')
INSERT [dbo].[FriendInfo] ([Fid], [Fname], [Lname], [Phone], [Gender], [DOB], [yymmdd], [id], [Upassword], [Image], [maritalStatus], [sc], [dc], [UserId]) VALUES (N'202406075', N'PRIYANSHI', N'MITRA', N'0900999999', N'F', CAST(N'2024-06-07' AS Date), N'202467', N'5', N'GGgg@@99', ..., N'Not mentioned', N'37', N'736  ', N'priyanshi@gmail.com')
INSERT [dbo].[FriendInfo] ([Fid], [Fname], [Lname], [Phone], [Gender], [DOB], [yymmdd], [id], [Upassword], [Image], [maritalStatus], [sc], [dc], [UserId]) VALUES (N'202406081', N'A', N'SAHA', N'9999999999', N'M', CAST(N'2024-06-08' AS Date), N'202468', N'1', N'GGgg@@99', ..., N'Not mentioned', N'37', N'736  ', N'a@gmail.com')
INSERT [dbo].[FriendInfo] ([Fid], [Fname], [Lname], [Phone], [Gender], [DOB], [yymmdd], [id], [Upassword], [Image], [maritalStatus], [sc], [dc], [UserId]) VALUES (N'202406091', N'ARGHA', N'SAHA', N'9999999999', N'M', CAST(N'2024-06-09' AS Date), N'202469', N'1', N'GGgg@@99', ..., N'Not mentioned', N'11', N'157  ', N'sahagarga000@gmail.com')
INSERT [dbo].[FriendInfo] ([Fid], [Fname], [Lname], [Phone], [Gender], [DOB], [yymmdd], [id], [Upassword], [Image], [maritalStatus], [sc], [dc], [UserId]) VALUES (N'202406092', N'IRFAN', N'KHAN', N'8918765932', N'M', CAST(N'2024-06-09' AS Date), N'202469', N'2', N'GGgg@@99', ..., N'Not mentioned', N'37', N'736  ', N'ik356483@gmail.com')
INSERT [dbo].[FriendInfo] ([Fid], [Fname], [Lname], [Phone], [Gender], [DOB], [yymmdd], [id], [Upassword], [Image], [maritalStatus], [sc], [dc], [UserId]) VALUES (N'202406121', N'TOUSIF', N'REZA', N'9641585727', N'M', CAST(N'2002-11-17' AS Date), N'2024612', N'1', N'GGgg@@99', ..., N'Married', N'12', N'173  ', N'tousif.reza511@gmail.com')
INSERT [dbo].[FriendInfo] ([Fid], [Fname], [Lname], [Phone], [Gender], [DOB], [yymmdd], [id], [Upassword], [Image], [maritalStatus], [sc], [dc], [UserId]) VALUES (N'202407111', N'GARGA', N'SAHA', N'0567898765', N'M', CAST(N'2002-08-30' AS Date), N'2024711', N'1', N'GGgg@@99', ..., N'Not mentioned', N'37', N'736  ', N'gargasaha1944@gmail.com')
GO

-- %% [markdown]
-- # [dbo].[FriendList]

-- %%
INSERT [dbo].[FriendList] ([Fid], [FriendId]) VALUES (N'202406074', N'202406072')
INSERT [dbo].[FriendList] ([Fid], [FriendId]) VALUES (N'202406071', N'202406072')
INSERT [dbo].[FriendList] ([Fid], [FriendId]) VALUES (N'202406071', N'202406073')
INSERT [dbo].[FriendList] ([Fid], [FriendId]) VALUES (N'202406091', N'202406071')
INSERT [dbo].[FriendList] ([Fid], [FriendId]) VALUES (N'202406121', N'202406072')
INSERT [dbo].[FriendList] ([Fid], [FriendId]) VALUES (N'202406092', N'202406074')
INSERT [dbo].[FriendList] ([Fid], [FriendId]) VALUES (N'202406074', N'202406071')
INSERT [dbo].[FriendList] ([Fid], [FriendId]) VALUES (N'202406072', N'202406073')
GO

-- %% [markdown]
-- # [dbo].[FriendRequest]

-- %%
INSERT [dbo].[FriendRequest] ([Fid], [RFid]) VALUES (N'202406075', N'202406072')
INSERT [dbo].[FriendRequest] ([Fid], [RFid]) VALUES (N'202406071', N'202406121')
INSERT [dbo].[FriendRequest] ([Fid], [RFid]) VALUES (N'202407111', N'202406074')
INSERT [dbo].[FriendRequest] ([Fid], [RFid]) VALUES (N'202406091', N'202406072')
GO

-- %% [markdown]
-- # [dbo].[LiveUser]

-- %%
INSERT [dbo].[LiveUser] ([Fid], [LiveInfo]) VALUES (N'202406071', N'0')
INSERT [dbo].[LiveUser] ([Fid], [LiveInfo]) VALUES (N'202406074', N'1')
INSERT [dbo].[LiveUser] ([Fid], [LiveInfo]) VALUES (N'202406075', N'1')
INSERT [dbo].[LiveUser] ([Fid], [LiveInfo]) VALUES (N'202406081', N'0')
INSERT [dbo].[LiveUser] ([Fid], [LiveInfo]) VALUES (N'202406091', N'1')
INSERT [dbo].[LiveUser] ([Fid], [LiveInfo]) VALUES (N'202406092', N'0')
INSERT [dbo].[LiveUser] ([Fid], [LiveInfo]) VALUES (N'202406121', N'0')
INSERT [dbo].[LiveUser] ([Fid], [LiveInfo]) VALUES (N'202407111', N'1')
INSERT [dbo].[LiveUser] ([Fid], [LiveInfo]) VALUES (N'202406072', N'0')
INSERT [dbo].[LiveUser] ([Fid], [LiveInfo]) VALUES (N'202406073', N'1')
GO

-- %% [markdown]
-- # [dbo].[State]

-- %%
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'01', N'ANDAMAN NICOBAR                                                                                     ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'02', N'Andhra Pradesh                                                                                      ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'03', N'Arunachal Pradesh                                                                                   ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'04', N'ASSAM                                                                                               ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'05', N'BIHAR                                                                                               ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'06', N'CHANDIGARH                                                                                          ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'07', N'CHHATTISGARH                                                                                        ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'08', N'DADRA NAGAR HAVELI                                                                                  ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'09', N'DAMAN DIU                                                                                           ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'10', N'DELHI                                                                                               ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'11', N'GOA                                                                                                 ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'12', N'GUJARAT                                                                                             ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'13', N'HARYANA                                                                                             ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'14', N'HIMACHAL PRADESH                                                                                    ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'15', N'JAMMU KASHMIR                                                                                       ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'16', N'JHARKHAND                                                                                           ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'17', N'KARNATAKA                                                                                           ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'18', N'KERALA                                                                                              ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'19', N'LADAKH                                                                                              ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'20', N'LAKSHADWEEP                                                                                         ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'21', N'MADHYA PRADESH                                                                                      ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'22', N' MAHARASHTRA                                                                                        ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'23', N'MANIPUR                                                                                             ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'24', N'MEGHALAYA                                                                                           ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'25', N'MIZORAM                                                                                             ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'26', N'NAGALAND                                                                                            ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'27', N'ODISHA                                                                                              ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'28', N'PUDUCHERRY                                                                                          ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'29', N'PUNJAB                                                                                              ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'30', N'RAJASTHAN                                                                                           ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'31', N'SIKKIM                                                                                              ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'32', N'TAMIL NADU                                                                                          ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'33', N'TELANGANA                                                                                           ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'34', N'TRIPURA                                                                                             ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'35', N'UTTAR PRADESH                                                                                       ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'36', N'UTTARAKHAND                                                                                         ')
INSERT [dbo].[State] ([cStateCode], [cStateName]) VALUES (N'37', N'WEST BENGAL                                                                                         ')
GO

-- %% [markdown]
-- # [dbo].[vf]

-- %%
INSERT [dbo].[vf] ([otp], [tm], [Email]) VALUES (CAST(1060 AS Numeric(4, 0)), CAST(N'2024-06-05T19:18:53.927' AS DateTime), N'gargasaha1945@gmail.com')
INSERT [dbo].[vf] ([otp], [tm], [Email]) VALUES (CAST(5665 AS Numeric(4, 0)), CAST(N'2024-06-03T22:37:49.567' AS DateTime), N'sahagarga@gmail.com')
INSERT [dbo].[vf] ([otp], [tm], [Email]) VALUES (CAST(9481 AS Numeric(4, 0)), CAST(N'2024-06-12T23:37:24.367' AS DateTime), N'tousif.reza511@gmaill.com')
GO

-- %% [markdown]
-- # [dbo].[vf2]

-- %%
INSERT [dbo].[vf2] ([Email], [otp], [tm]) VALUES (N'sahagarga@gmail.com', CAST(8458 AS Numeric(4, 0)), CAST(N'2024-02-08T12:38:24.690' AS DateTime))
GO

-- %% [markdown]
-- # [dbo].[Working]

-- %%
INSERT [dbo].[Working] ([Fid], [workingStatus], [Wid]) VALUES (N'202406121', N'Personal Business', N'1')
INSERT [dbo].[Working] ([Fid], [workingStatus], [Wid]) VALUES (N'202406074', N'ASP.NET DEVELOPER', N'2')
GO

-- %% [markdown]
-- # [FK__ChatTable__fromF__7EF6D905]

-- %%
ALTER TABLE [dbo].[ChatTable]  WITH CHECK ADD FOREIGN KEY([fromFid])
REFERENCES [dbo].[FriendInfo] ([Fid])
GO

-- %% [markdown]
-- # [FK__ChatTable__toFid__7FEAFD3E]

-- %%
ALTER TABLE [dbo].[ChatTable]  WITH CHECK ADD FOREIGN KEY([toFid])
REFERENCES [dbo].[FriendInfo] ([Fid])
GO

-- %% [markdown]
-- # [FK__Education__Fid__00DF2177]

-- %%
ALTER TABLE [dbo].[Education]  WITH CHECK ADD FOREIGN KEY([Fid])
REFERENCES [dbo].[FriendInfo] ([Fid])
GO

-- %% [markdown]
-- # [FK__FriendLis__Frien__03BB8E22]

-- %%
ALTER TABLE [dbo].[FriendList]  WITH CHECK ADD FOREIGN KEY([FriendId])
REFERENCES [dbo].[FriendInfo] ([Fid])
GO

-- %% [markdown]
-- # [FK__FriendList__Fid__02C769E9]

-- %%
ALTER TABLE [dbo].[FriendList]  WITH CHECK ADD FOREIGN KEY([Fid])
REFERENCES [dbo].[FriendInfo] ([Fid])
GO

-- %% [markdown]
-- # [FK__FriendRequ__RFid__05A3D694]

-- %%
ALTER TABLE [dbo].[FriendRequest]  WITH CHECK ADD FOREIGN KEY([RFid])
REFERENCES [dbo].[FriendInfo] ([Fid])
GO

-- %% [markdown]
-- # [FK__FriendReque__Fid__04AFB25B]

-- %%
ALTER TABLE [dbo].[FriendRequest]  WITH CHECK ADD FOREIGN KEY([Fid])
REFERENCES [dbo].[FriendInfo] ([Fid])
GO

-- %% [markdown]
-- # [FK__LiveUser__Fid__0697FACD]

-- %%
ALTER TABLE [dbo].[LiveUser]  WITH CHECK ADD FOREIGN KEY([Fid])
REFERENCES [dbo].[FriendInfo] ([Fid])
GO

-- %% [markdown]
-- # [FK__Working__Fid__01D345B0]

-- %%
ALTER TABLE [dbo].[Working]  WITH CHECK ADD FOREIGN KEY([Fid])
REFERENCES [dbo].[FriendInfo] ([Fid])
GO

-- %% [markdown]
-- # [dbo].[getchat]

-- %%
/****** Object:  StoredProcedure [dbo].[getchat]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[getchat]
@Fid varchar(16),
@CFid varchar(16)
as 
begin
	select top 50 * from ChatTable where (fromFid=@Fid and toFid=@CFid) or (toFid=@Fid and fromFid=@CFid) order by Mdate;
end
GO

-- %% [markdown]
-- # [dbo].[getchatonemessage]

-- %%
/****** Object:  StoredProcedure [dbo].[getchatonemessage]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create proc [dbo].[getchatonemessage]
@Fid varchar(16),
@CFid varchar(16)
as
begin
	select top 1 * from ChatTable where (fromFid=@Fid and toFid=@CFid) or (toFid=@Fid and fromFid=@CFid) order by Mdate desc;
end
GO

-- %% [markdown]
-- # [dbo].[insertchat]

-- %%
/****** Object:  StoredProcedure [dbo].[insertchat]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[insertchat]
@Mode varchar(1),
@Fid varchar(16),
@CFid varchar(16),
@msg varchar(1000),
@Image varbinary(max)
as
begin
	if @mode = 0
	begin
		insert into ChatTable values(@Fid,@CFid,@msg,GETDATE(),@Mode);
	end
	else if @mode = 1
	begin
		if exists(select *from ChatImageTable)
		begin
			declare @temp varchar(100);
			set @temp=(select max(CAST((Num) as int)) from ChatImageTable);
			declare @counter int;
			set @counter=CAST(@temp as int);
			set @counter=@counter+1;
			set @temp=CAST(@counter as varchar(100));
			insert into ChatTable values(@Fid,@CFid,@temp,GETDATE(),@Mode);
			insert into ChatImageTable values(@temp,@Image);
		end
		else
		begin
			insert into ChatTable values(@Fid,@CFid,'1',GETDATE(),@Mode);
			insert into ChatImageTable values('1',@Image);
		end
	end
end
GO

-- %% [markdown]
-- # [dbo].[insertEducation]

-- %%
/****** Object:  StoredProcedure [dbo].[insertEducation]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[insertEducation]
@Fid varchar(16),
@educationstatus varchar(100)
as 
begin
	if not exists(select *from Education)
		begin
			insert into Education values(@Fid,@educationstatus,'1');
		end
	else
		begin
			declare @max int;
			set @max=(select max(CAST((Eid) as int)) from Education)+1;
			insert into Education values(@Fid,@educationstatus,cast(@max as varchar(100)));
		end
end
GO

-- %% [markdown]
-- # [dbo].[insertOtp]

-- %%
/****** Object:  StoredProcedure [dbo].[insertOtp]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[insertOtp]
@Email varchar(50),
@otp numeric(4)
as 
begin
	delete from vf where Email=@Email;
	insert into vf values(@otp,GETDATE(),@Email);
end
GO

-- %% [markdown]
-- # [dbo].[insertOtp2]

-- %%
/****** Object:  StoredProcedure [dbo].[insertOtp2]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[insertOtp2]
@Email varchar(50),
@otp numeric(4)
as 
begin
	delete from vf2 where Email=@Email;
	insert into vf2 values(@Email,@otp,GETDATE());
end
GO

-- %% [markdown]
-- # [dbo].[insertWork]

-- %%
/****** Object:  StoredProcedure [dbo].[insertWork]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[insertWork]
@Fid varchar(16),
@workingstatus varchar(100)
as 
begin
	if not exists(select *from working)
		begin
			insert into Working values(@Fid,@workingstatus,'1');
		end
	else
		begin
			declare @max int;
			set @max=(select max(CAST((Wid) as int)) from Working)+1;
			insert into Working values(@Fid,@workingstatus,cast(@max as varchar(100)));
		end
end
GO

-- %% [markdown]
-- # [dbo].[listFromAddFriend]

-- %%
/****** Object:  StoredProcedure [dbo].[listFromAddFriend]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[listFromAddFriend]
@Fid varchar(16)
as
begin
	select Fname,Lname,Image,Fid from FriendInfo where Fid!=@Fid and Fid not in (select RFid from FriendRequest where Fid=@Fid) and Fid not in (select Fid from FriendRequest where RFid=@Fid) and Fid not in (select FriendId from FriendList where Fid=@Fid) and Fid not in (select Fid from FriendList where FriendId=@Fid);
end

GO

-- %% [markdown]
-- # [dbo].[listFromfriendRequest]

-- %%
/****** Object:  StoredProcedure [dbo].[listFromfriendRequest]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[listFromfriendRequest]
@Fid varchar(16)
as 
begin
	select Fname,Lname,Image,Fid from FriendInfo where Fid in (select Fid from FriendRequest where RFid=@Fid) and Fid not in (select FriendId from FriendList where Fid=@Fid)
end
GO

-- %% [markdown]
-- # [dbo].[listFromOfflineFriend]

-- %%
/****** Object:  StoredProcedure [dbo].[listFromOfflineFriend]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[listFromOfflineFriend]
@Fid varchar(16)
as 
begin
	select Fname,Lname,Image,Fid from FriendInfo where Fid in (select Fid from LiveUser where LiveInfo like('0') and (Fid in (select Fid from FriendList where FriendId like(@Fid)) or Fid in (select FriendId from FriendList where Fid like(@Fid))))
end

GO

-- %% [markdown]
-- # [dbo].[listFromOnlineFriend]

-- %%
/****** Object:  StoredProcedure [dbo].[listFromOnlineFriend]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[listFromOnlineFriend]
@Fid varchar(16)
as 
begin
	select Fname,Lname,Image,Fid from FriendInfo where Fid in (select Fid from LiveUser where (Fid in (select Fid from FriendList where FriendId like(@Fid)) or Fid in (select FriendId from FriendList where Fid like(@Fid))))
end

GO

-- %% [markdown]
-- # [dbo].[Register]

-- %%
/****** Object:  StoredProcedure [dbo].[Register]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[Register]
@UserNameF varchar(100),
@UserNameL varchar(100),
@Phone varchar(10),
@UserImage varbinary(max),
@Gender varchar(1),
@DOB date,
@UserPassword varchar(8),
@Email varchar(50),
@sc varchar(100),
@dc varchar(100)
as 
begin
	--developed by gs
	if exists(select * from FriendInfo  where UserId=@Email)
				select 0;
				
	else
		begin
			if not exists(select *from FriendInfo)
		begin
			--get verified if account exists or not
			




			--get year part 
			
			declare @id varchar(16);
			set @id=year(getdate());
			
			--get month part 
			
			if LEN(month(getdate())) = 1
				set @id=concat(@id,'0',month(getdate()));
			else
				set @id=concat(@id,MONTH(getdate()));

			--get day part
			if LEN(DAY(getdate())) = 1
				set @id=concat(@id,'0',day(getdate()))
			else 
				set @id=concat(@id,DAY(getdate()));
			set @id=concat(@id,'1');
			declare @d1 varchar(8);
			set @d1=Concat(YEAR(getdate()),month(GETDATE()),DAY(GETDATE()));
			
			--print 'ran1'
			--insert into UserInfo values(@id,@Phone,@UserImage,@Gender,@DOB,@d1,'1',@UserPassword,@UserNameF,@UserNameL,@Email,@StateCode,@DistCode);
			--insert into FriendDFA values(@id,@Email,@UserPassword,1);
			insert into FriendInfo values(@id,@UserNameF,@UserNameL,@Phone,@Gender,@DOB,@d1,'1',@UserPassword,@UserImage,'Not mentioned',@sc,@dc,@Email);
			insert into LiveUser values(@id,'1');
			select 1,@id;
			
		end
	else
		begin
			declare @d2 varchar(8);
			set @d2=Concat(YEAR(getdate()),month(GETDATE()),DAY(GETDATE()));
			if exists(select * from FriendInfo where yymmdd=@d2)
				begin
					declare @maxid numeric(8);
					set @maxid=(select max(CAST((id) as numeric(8))) from FriendInfo where yymmdd=@d2)+1;
					declare @iid varchar(16);
					--get year part
					set @iid=year(getdate());
			
					--get month part 
			
					if LEN(month(getdate())) = 1
						set @iid=concat(@iid,'0',month(getdate()));
					else
						set @iid=concat(@iid,MONTH(getdate()));

					--get day part
					if LEN(DAY(getdate())) = 1
						set @iid=concat(@iid,'0',day(getdate()))
					else 
						set @iid=concat(@iid,DAY(getdate()));
					set @iid=concat(@iid,CAST(@maxid as varchar(8)));
					
					--print 'ran2'
					--insert into UserInfo values(@iid,@Phone,@UserImage,@Gender,@DOB,@d2,@maxid,@UserPassword,@UserNameF,@UserNameL,@Email,@StateCode,@DistCode);
					--insert into FriendDFA values(@iid,@Email,@UserPassword,1);
					insert into FriendInfo values(@iid,@UserNameF,@UserNameL,@Phone,@Gender,@DOB,@d2,@maxid,@UserPassword,@UserImage,'Not mentioned',@sc,@dc,@Email);
					insert into LiveUser values(@iid,'1');
					select 1,@iid;
				end
			else
				begin
					declare @iiid varchar(16);
					--get year part
					set @iiid=year(getdate());
			
					--get month part 
			
					if LEN(month(getdate())) = 1
						set @iiid=concat(@iiid,'0',month(getdate()));
					else
						set @iiid=concat(@iiid,MONTH(getdate()));

					--get day part
					if LEN(DAY(getdate())) = 1
						set @iiid=concat(@iiid,'0',day(getdate()))
					else 
						set @iiid=concat(@iiid,DAY(getdate()));
					set @iiid=concat(@iiid,'1');
					
					--print 'ran3'
					--insert into UserInfo values(@iiid,@Phone,@UserImage,@Gender,@DOB,@d2,'1',@UserPassword,@UserNameF,@UserNameL,@Email,@StateCode,@DistCode);
					--insert into FriendDFA values(@iiid,@Email,@UserPassword,1);
					insert into FriendInfo values(@iiid,@UserNameF,@UserNameL,@Phone,@Gender,@DOB,@d2,'1',@UserPassword,@UserImage,'Not mentioned',@sc,@dc,@Email);
					insert into LiveUser values(@iiid,'1');
					select 1,@iiid;
				end
		end
		end
	
end



GO

-- %% [markdown]
-- # [dbo].[searchFrnd]

-- %%
/****** Object:  StoredProcedure [dbo].[searchFrnd]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[searchFrnd]
@Fname varchar(50),
@Lname varchar(50),
@Fid varchar(16)
as
begin
	set @Fname='%'+@Fname+'%';
	set @Lname='%'+@Lname+'%';
	select Fname,Lname,Image,Fid from FriendInfo where Fid!=@Fid and (Fid in (select Fid from FriendList where FriendId like(@Fid)) or Fid in (select FriendId from FriendList where Fid like(@Fid))) and (((Fname like @Fname) and (Lname like @Lname)) or (Lname like @Fname))
	/*select Fname,Lname,Image,Fid from FriendInfo where Fid!=@Fid and Fid in (select friendid from FriendList where Fid=@Fid) or Fid in (select Fid from FriendList where FriendId=@Fid) and (((Fname like @Fname) and (Lname like @Lname)) /*or (Lname like @Fname)*/)*/
end

GO

-- %% [markdown]
-- # [dbo].[unfriend]

-- %%
/****** Object:  StoredProcedure [dbo].[unfriend]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[unfriend]
@Fid varchar(16),
@CFid varchar(16)
as
begin
	delete from ChatImageTable where Num in (select cast(msg as varchar(1000)) from ChatTable where fromFid=@Fid and toFid=@CFid and Mode='1');
	delete from ChatTable where (fromFid=@Fid and toFid=@CFid) or(fromFid=@CFid and toFid=@Fid)
	delete from FriendList where (Fid=@Fid and FriendId=@CFid) or (Fid=@CFid and FriendId=@Fid) 
end
GO

-- %% [markdown]
-- # [dbo].[updprofile]

-- %%
/****** Object:  StoredProcedure [dbo].[updprofile]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[updprofile]
@Fname varchar(50),
@Lname varchar(50),
@Phone varchar(10),

@DOB datetime,
@m varchar(30),

@Fid varchar(16)
as 
begin
	update FriendInfo set Fname=@Fname,Lname=@Lname,Phone=@Phone,DOB=@DOB,maritalStatus=@m where Fid=@Fid; 
end
GO

-- %% [markdown]
-- # [dbo].[verifyOtp]

-- %%
/****** Object:  StoredProcedure [dbo].[verifyOtp]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[verifyOtp]
@Email varchar(50),
@otp numeric(4)
as 
begin
	if exists(select *from vf where Email=@Email)
	begin
		declare @dd1 datetime
		set @dd1=CONVERT(TIME(0),GETDATE())
		declare @i numeric(3)
		set @i=SUBSTRING(CONVERT(varchar(100),@dd1),16,2)

		declare @dd2 datetime 
		set @dd2=(select tm from vf where Email=@Email)
		declare @j numeric(3)
		set @j=SUBSTRING(CONVERT(varchar(100),@dd2),16,2)
		/*select @i
		select @j*/
		if(@i<=@j+5)
		begin
			declare @num numeric(4)
			set @num=(select otp from vf where Email=@Email)
			if (@num=@otp)
			begin
				delete from vf where Email=@Email
				
				select 1;
			end
			else
				/*if otp is wrong*/
				select 3;
		end
		else
			/*if time limit exceeded*/
			select 4;

	end
	else
		/*if user not found*/
		select 2;
end


GO

-- %% [markdown]
-- # [dbo].[verifyOtp2]

-- %%
/****** Object:  StoredProcedure [dbo].[verifyOtp2]    Script Date: 7/13/2024 11:48:14 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[verifyOtp2]
@Email varchar(50),
@otp numeric(4)
as 
begin
	if exists(select *from vf2 where Email=@Email)
	begin
		declare @dd1 datetime
		set @dd1=CONVERT(TIME(0),GETDATE())
		declare @i numeric(3)
		set @i=SUBSTRING(CONVERT(varchar(100),@dd1),16,2)

		declare @dd2 datetime 
		set @dd2=(select tm from vf2 where Email=@Email)
		declare @j numeric(3)
		set @j=SUBSTRING(CONVERT(varchar(100),@dd2),16,2)
		/*select @i
		select @j*/
		if(@i<=@j+5)
		begin
			declare @num numeric(4)
			set @num=(select otp from vf2 where Email=@Email)
			if (@num=@otp)
			begin
				delete from vf2 where Email=@Email;
				select 1;
			end
			else
				/*if otp is wrong*/
				select 3;
		end
		else
			/*if time limit exceeded*/
			select 4;

	end
	else
		/*if user not found*/
		select 2;
end
GO
